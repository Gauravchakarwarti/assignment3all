# %% [markdown]
# #**PANUGANTI SAI LIKHITH**
#
# sailikithpaanuganti@gmail.com
#
# https://www.linkedin.com/in/sailikhith

# %% [markdown]
# # Dataset Required
#
# https://github.com/Sai-Likhith/Mobile-Price-Range-Prediction-A-Data-Science-Approach/blob/main/mobile_price_range_data.csv

# %% [markdown]
# #Importing Required Libraries

# %%
import pandas as pd
import numpy as np

from sklearn import preprocessing

from sklearn.model_selection import train_test_split

from sklearn import metrics
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %% [markdown]
# #Uploading csv file and Getting started

# %%
data1 = pd.read_csv(r"C:\Users\Administrator\Downloads\mobile_price_data.csv")  
data1.head()
#Reading the csv file and assigning the name for csv file as data1
# Out:
#                             mobile_name mobile_price mobile_color  dual_sim  \
# 0    Realme Narzo 10A (So White, 32 GB)       ₹8,999     So White  Dual Sim
# 1     Realme Narzo 10A (So Blue, 32 GB)       ₹8,999      So Blue  Dual Sim
# 2     Realme Narzo 10A (So Blue, 64 GB)       ₹9,999      So Blue  Dual Sim
# 3    Realme Narzo 10A (So White, 64 GB)       ₹9,999     So White  Dual Sim
# 4  Realme Narzo 10 (That Green, 128 GB)      ₹11,999   That Green  Dual Sim
#
#               disp_size         resolution          os  num_cores mp_speed  \
# 0  16.56 cm (6.52 inch)  1600 x 720 Pixels  Android 10  Octa Core    2 GHz
# 1  16.56 cm (6.52 inch)  1600 x 720 Pixels  Android 10  Octa Core    2 GHz
# 2  16.56 cm (6.52 inch)  1600 x 720 Pixels  Android 10  Octa Core    2 GHz
# 3  16.56 cm (6.52 inch)  1600 x 720 Pixels  Android 10  Octa Core    2 GHz
# 4   16.51 cm (6.5 inch)  1600 x 720 Pixels  Android 10  Octa Core    2 GHz
#
# ...

# %%
data1.columns
# Out:
# Index(['mobile_name', 'mobile_price', 'mobile_color', 'dual_sim', 'disp_size',
#        'resolution', 'os', 'num_cores', 'mp_speed', 'int_memory', 'ram',
#        'p_cam', 'f_cam', 'network', 'bluetooth', 'battery_power', 'mob_width',
#        'mob_height', 'mob_depth', 'mob_weight'],
#       dtype='object')

# %%
data1.isnull().sum()
# Out:
# mobile_name      0
# mobile_price     0
# mobile_color     0
# dual_sim         0
# disp_size        0
# resolution       0
# os               0
# num_cores        0
# mp_speed         0
# int_memory       0
# ram              0
# p_cam            0
# f_cam            0
# network          0
# bluetooth        0
# battery_power    0
# mob_width        0
# mob_height       0
# mob_depth        0
# mob_weight       0
# dtype: int64

# %% [markdown]
# df = df.replace('[\$,]', '', regex=True).astype(float)
# carSales["Price"] = carSales["Price"].replace("[$,]", "", regex=True).astype(int))

# %%
data1['mobile_price']
# Out:
# 0       ₹8,999
# 1       ₹8,999
# 2       ₹9,999
# 3       ₹9,999
# 4      ₹11,999
#         ...
# 454    ₹13,490
# 455     ₹9,490
# 456    ₹22,990
# 457    ₹13,990
# 458    ₹13,990
# Name: mobile_price, Length: 459, dtype: object

# %%
data1.dropna()
data1
# Out:
#                               mobile_name mobile_price     mobile_color  \
# 0      Realme Narzo 10A (So White, 32 GB)       ₹8,999         So White
# 1       Realme Narzo 10A (So Blue, 32 GB)       ₹8,999          So Blue
# 2       Realme Narzo 10A (So Blue, 64 GB)       ₹9,999          So Blue
# 3      Realme Narzo 10A (So White, 64 GB)       ₹9,999         So White
# 4    Realme Narzo 10 (That Green, 128 GB)      ₹11,999       That Green
# ..                                    ...          ...              ...
# 454               OPPO A83 (Black, 32 GB)      ₹13,490            Black
# 455                 OPPO A83 (Red, 16 GB)       ₹9,490              Red
# 456                  OPPO F7 (Red, 64 GB)      ₹22,990              Red
# 457       OPPO F11 (Marble Green, 128 GB)      ₹13,990     Marble Green
# 458    OPPO F11 (Fluorite Purple, 128 GB)      ₹13,990  Fluorite Purple
#
#      dual_sim             disp_size          resolution                  os  \
# ...

# %%
data1['mobile_price']
# Out:
# 0       ₹8,999
# 1       ₹8,999
# 2       ₹9,999
# 3       ₹9,999
# 4      ₹11,999
#         ...
# 454    ₹13,490
# 455     ₹9,490
# 456    ₹22,990
# 457    ₹13,990
# 458    ₹13,990
# Name: mobile_price, Length: 459, dtype: object

# %%
data1["mobile_price"] = data1["mobile_price"].replace("[₹,]", "", regex=True).astype(int)

# %%
data1
# Out:
#                               mobile_name  mobile_price     mobile_color  \
# 0      Realme Narzo 10A (So White, 32 GB)          8999         So White
# 1       Realme Narzo 10A (So Blue, 32 GB)          8999          So Blue
# 2       Realme Narzo 10A (So Blue, 64 GB)          9999          So Blue
# 3      Realme Narzo 10A (So White, 64 GB)          9999         So White
# 4    Realme Narzo 10 (That Green, 128 GB)         11999       That Green
# ..                                    ...           ...              ...
# 454               OPPO A83 (Black, 32 GB)         13490            Black
# 455                 OPPO A83 (Red, 16 GB)          9490              Red
# 456                  OPPO F7 (Red, 64 GB)         22990              Red
# 457       OPPO F11 (Marble Green, 128 GB)         13990     Marble Green
# 458    OPPO F11 (Fluorite Purple, 128 GB)         13990  Fluorite Purple
#
#      dual_sim             disp_size          resolution                  os  \
# ...

# %%
data1.rename(columns = {'mobile_price':'mobile_price(₹)'}, inplace = True)
data1
# Out:
#                               mobile_name  mobile_price(₹)     mobile_color  \
# 0      Realme Narzo 10A (So White, 32 GB)             8999         So White
# 1       Realme Narzo 10A (So Blue, 32 GB)             8999          So Blue
# 2       Realme Narzo 10A (So Blue, 64 GB)             9999          So Blue
# 3      Realme Narzo 10A (So White, 64 GB)             9999         So White
# 4    Realme Narzo 10 (That Green, 128 GB)            11999       That Green
# ..                                    ...              ...              ...
# 454               OPPO A83 (Black, 32 GB)            13490            Black
# 455                 OPPO A83 (Red, 16 GB)             9490              Red
# 456                  OPPO F7 (Red, 64 GB)            22990              Red
# 457       OPPO F11 (Marble Green, 128 GB)            13990     Marble Green
# 458    OPPO F11 (Fluorite Purple, 128 GB)            13990  Fluorite Purple
#
# ...

# %%
pd.isnull(data).sum()
# Out:
# mobile_name      0
# mobile_color     0
# dual_sim         0
# disp_size        0
# resolution       0
# os               0
# num_cores        0
# mp_speed         0
# int_memory       0
# ram              0
# p_cam            0
# f_cam            0
# network          0
# bluetooth        0
# battery_power    0
# mob_width        0
# mob_height       0
# mob_depth        0
# mob_weight       0
# dtype: int64

# %%
data = data.dropna(axis=0,inplace=False)

# %%
data1.columns
# Out:
# Index(['mobile_name', 'mobile_price', 'mobile_color', 'dual_sim', 'disp_size',
#        'resolution', 'os', 'num_cores', 'mp_speed', 'int_memory', 'ram',
#        'p_cam', 'f_cam', 'network', 'bluetooth', 'battery_power', 'mob_width',
#        'mob_height', 'mob_depth', 'mob_weight'],
#       dtype='object')

# %% [markdown]
# #Price Range

# %%
y = data1['mobile_price']
x = data

# %%
y.unique()
# Out:
# array([ 8999,  9999, 11999, 14999, 16999, 13999, 35999, 31999, 15490,
#        41999, 46999, 19999,  6999,  7499, 17999, 10999, 29999, 36999,
#        20999,  6499, 25999, 24999, 27999, 32999,  8499,  9499, 10499,
#         9799, 16939, 17350, 21999, 13495, 15990, 55799, 51800, 16899,
#        12999, 16998,  7399, 11199, 13261, 10978, 11280, 10100,  7450,
#        55400,  6700,  6699,  7999,  8369,  8090,  8498,  9990, 11349,
#        14800, 13990,  8689, 11599,  9900, 10990, 10849, 16990, 18990,
#        12990, 19990,  8990, 11982, 17990,  8705,  8949, 16375, 31990,
#        27990, 24990, 11990,  9199, 22399, 21099, 29499, 11490, 28499,
#        28990, 29990, 15500, 14990, 18900, 24000,  8900, 11500, 10900,
#        12000, 22325, 13995, 13529,  8998, 14914, 14538, 17490, 16499,
#        18499, 15999,  6299, 19900, 47999,  6000, 20995, 11995, 10995,
#        11499,  7699,  7599,  9599, 18999, 22999, 21499, 17499, 12490,
# ...

# %%
values = [30, 40, 20, 10]
labels = ['Category A', 'Category B', 'Category C', 'Category D']
colors = ['lightcoral', 'turquoise', 'yellowgreen', 'dimgray']


if len(values) != len(labels):
    raise ValueError("The length of 'values' must be equal to the length of 'labels'")


fig1, ax1 = plt.subplots()
ax1.pie(values, labels=labels, colors=colors, autopct='%1.1f%%', shadow=False, startangle=90)
ax1.set_title('Balanced or Unbalanced?')
plt.show()

# %% [markdown]
# #Spliting data into training and testing data

# %%
from numpy.random import RandomState
rng = RandomState()



train = data.sample(frac=0.9, random_state=rng)
test = data.loc[~data.index.isin(train.index)]

# %%
train
# Out:
#                                mobile_name    mobile_color  dual_sim  \
# 141  Redmi Note 7 Pro (Space Black, 64 GB)     Space Black  Dual Sim
# 309      Infinix Hot 9 (Ocean Wave, 64 GB)      Ocean Wave  Dual Sim
# 227        Vivo Y91i (Fusion Black, 16 GB)    Fusion Black  Dual Sim
# 362            POCO F1 (Steel Blue, 64 GB)      Steel Blue  Dual Sim
# 109         Redmi 8 (Emerald Green, 64 GB)   Emerald Green  Dual Sim
# ..                                     ...             ...       ...
# 67        Realme X3 (Arctic White, 128 GB)    Arctic White  Dual Sim
# 214      Vivo Y19 (Magnetic Black, 128 GB)  Magnetic Black  Dual Sim
# 224         Vivo S1 (Skyline Blue, 128 GB)    Skyline Blue  Dual Sim
# 174                     Mi A2 (Red, 64 GB)             Red  Dual Sim
# 319     Infinix Hot 7 (Mocha Brown, 64 GB)     Mocha Brown  Dual Sim
#
#                 disp_size          resolution                os  num_cores  \
# ...

# %%
test
# Out:
#                                   mobile_name       mobile_color  dual_sim  \
# 5        Realme Narzo 10 (That White, 128 GB)         That White  Dual Sim
# 9        Realme 5 Pro (Sparkling Blue, 64 GB)     Sparkling Blue  Dual Sim
# 18        Realme X50 Pro (Moss Green, 128 GB)         Moss Green  Dual Sim
# 50          Realme 5s (Crystal Purple, 64 GB)     Crystal Purple  Dual Sim
# 65           Realme X3 (Glacier Blue, 128 GB)       Glacier Blue  Dual Sim
# 77             Realme 3 (Radiant Blue, 64 GB)       Radiant Blue  Dual Sim
# 87              Mi A3 (Not just Blue, 128 GB)      Not just Blue  Dual Sim
# 89        Redmi K20 Pro (Pearl White, 128 GB)        Pearl White  Dual Sim
# 105                 Mi A2 (Lake Blue, 128 GB)          Lake Blue  Dual Sim
# 112               Mi A3 (Kind of Grey, 64 GB)       Kind of Grey  Dual Sim
# 116           Redmi 8A Dual (Sea Blue, 32 GB)           Sea Blue  Dual Sim
# ...

# %%
train.index
# Out:
# Index([141, 309, 227, 362, 109, 104, 192, 233,  72, 274,
#        ...
#        334, 257, 420,  73, 379,  67, 214, 224, 174, 319],
#       dtype='int64', length=413)

# %%
y_train = y[train.index]

# %%
y_test = y[test.index]

# %%
y_train
# Out:
# 141    10999
# 309     8999
# 227     9199
# 362    19999
# 109     9799
#        ...
# 67     25999
# 214    16375
# 224    19990
# 174    13999
# 319     9999
# Name: mobile_price, Length: 413, dtype: int32

# %%
y_test
# Out:
# 5      11999
# 9      13999
# 18     41999
# 50     10999
# 65     25999
# 77     10499
# 87     14999
# 89     24999
# 105    16899
# 112    12999
# 116     7399
# 120    10978
# 149     6700
# 156     8499
# 160     9999
# 177     6700
# 197    16990
# 201    10849
# 207    17990
# 212     8705
# 236    29990
# 249    10990
# 265    11990
# 267    14990
# 269    18900
# 273     8900
# 275    13990
# 285     8998
# 294    18499
# 298     6299
# 352    21499
# 366    13999
# 367    16999
# 374    14990
# 381    18990
# 396    41990
# 406    18989
# 413    19600
# 422    11490
# 427     9490
# 435    11990
# 438    18000
# 440    13990
# 441    17000
# 450    11490
# 457    13990
# Name: mobile_price, dtype: int32

# %%
print(train.shape)
print(test.shape)
# Out:
# (413, 19)
# (46, 19)

# %% [markdown]
# #Correlations between the Attributes
